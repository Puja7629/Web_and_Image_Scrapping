# %%
import requests
from bs4 import *
from PIL import Image
import matplotlib.pyplot as plt
link= input("input your link:")
req=requests.get(link)
soup=BeautifulSoup(req.text,'lxml')
imgs=soup.find_all('img')
k=1
for i in imgs:
    try:
        url=i['src']
        print('Image link:',k)
        print(url)
        response=requests.get(url,stream=True)
        img=Image.open(response.raw)
        plt.imshow(img)
        plt.close()
        img.save('C:/Users/Lenovo/Desktop/Image scrapping/'+str(k)+'.jpg')
    except:
         KeyError
    k+=1
# Out:
# input your link:https://www.amazon.in/Laptops/b/ref=nav_shopall_sbc_mobcomp_laptops?ie=UTF8&node=1375424031
# Image link: 1
# https://images-na.ssl-images-amazon.com/images/G/31/gno/sprites/nav-sprite-global_bluebeacon-V3-1x_optimized._CB516557522_.png
# Image link: 2
# https://images-eu.ssl-images-amazon.com/images/G/31/x-locale/common/transparent-pixel._CB386942716_.gif
# Image link: 3
# https://images-na.ssl-images-amazon.com/images/G/31/img18/Electronics/Megamenu/Megamenu_Electronics_top._CB502737186_.png
# Image link: 4
# https://images-na.ssl-images-amazon.com/images/G/01/x-locale/common/transparent-pixel._CB386942464_.gif
# Image link: 5
# https://images-eu.ssl-images-amazon.com/images/G/31/img18/PC/Laptops/EMIfest/D8469662_IN_PC_EMIFest_HDFC_December_1500x150.jpg
# Image link: 6
# https://images-eu.ssl-images-amazon.com/images/G/31/img18/PC/Laptops/Buyingguide/V83054589_IN_PC_Laptops_buyingguide_tile_1500X300._CB460227348_.jpg
# Image link: 7
# ...

# %%
import requests
from bs4 import *
from PIL import Image
import matplotlib.pyplot as plt
link= input("input your link:")
req=requests.get(link)
soup=BeautifulSoup(req.text,'lxml')
imgs=soup.find_all('img')
k=1
for i in imgs:
    try:
        url=i['src']
        print('Image link:',k)
        print(url)
        response=requests.get(url,stream=True)
        img=Image.open(response.raw)
        plt.imshow(img)
        plt.close()
        img.save('C:/Users/Lenovo/Desktop/Image scrapping/'+str(k)+'.jpg')
    except:
         KeyError
    k+=1
# Out:
# input your link:https://www.flipkart.com/redmi-note-6-pro-black-64-gb/p/itmfayzxqnzjhtbh?pid=MOBFAJB4CWKAZGPZ&srno=b_1_1&otracker=hp_omu_Mobile%2BNew%2BLaunches_1_57RF2Z45L2RL_5&lid=LSTMOBFAJB4CWKAZGPZVOYNQH&fm=neo%2Fmerchandising&iid=fef9f652-aceb-497c-9eba-96f4d7adc847.MOBFAJB4CWKAZGPZ.SEARCH&ppt=Homepage&ppn=Homepage&ssid=a8vewa8e1s0000001547100890836
# Image link: 1
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png
# Image link: 2
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/plus_b13a8b.png
# Image link: 3
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/placeholder_9951d0.svg
# Image link: 5
# ...: 6
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fa_8b4b59.png
# Image link: 7
# //img1a.flixcart.com/www/linchpin/fk-cp-zion/img/info-basic_ea3ba2.svg
# Image link: 8
# https://rukminim1.flixcart.com/www/36/36/promos/06/09/2016/49f16fff-0a9d-48bf-a6e6-5980c9852f11.png?q=90
# Image link: 9
# ...: 10
# ...

# %%
response=requests.get(url,stream=True)
img=Image.open(response.raw)
plt.imshow(img)
plt.close()
img.save('C:/Users/Lenovo/Desktop/Image scrapping/'+''+'.jpg')

# %%
#file handling
file=open("testp.txt","w")

# %%
dir(file)
# Out:
# ['_CHUNK_SIZE',
#  '__class__',
#  '__del__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__next__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_checkClosed',
#  '_checkReadable',
#  '_checkSeekable',
#  '_checkWritable',
#  '_finalizing',
#  'buffer',
#  'close',
#  'closed',
#  'detach',
#  'encoding',
#  'errors',
#  'fileno',
#  'flush',
#  'isatty',
#  'line_buffering',
#  'mode',
#  'name',
#  'newlines',
#  'read',
#  'readable',
#  'readline',
#  'readlines',
#  'reconfigure',
#  'seek',
#  'seekable',
#  'tell',
#  'truncate',
#  'writable',
#  'write',
#  'write_through',
#  'writelines']

# %%
file.writelines("hey,i am puja")

# %%
file.writelines("hello,i am programmer")

# %%
file.close()

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 3E6A-E9A2
#
#  Directory of C:\Users\Lenovo\Desktop\Python Bottcamp
#
# 02-01-2019  12:51    <DIR>          .
# 02-01-2019  12:51    <DIR>          ..
# 31-12-2018  20:29             9,434  #day_1 27 december.ipynb
# 31-12-2018  12:27         6,660,049  #day_3 29 december.ipynb
# 31-12-2018  11:54             5,685  #day_4 31 december.ipynb
# 02-01-2019  12:51            12,462  #day_5 2nd january, web page image scrapper..ipynb
# 31-12-2018  10:24             3,528  ATM Prototype code in python.ipynb
# 01-01-2019  19:51             2,251  Web scrapping.ipynb
# 29-12-2018  09:20            13,407 #day_2 28 december.ipynb
# 02-01-2019  12:36    <DIR>          .ipynb_checkpoints
# 29-12-2018  11:03             3,688 Assignment_1(D1).ipynb
# 29-12-2018  18:23             5,666 Assignment_2(D2).ipynb
# 31-12-2018  11:30             4,981 Assignment_3(D3).ipynb
# 02-01-2019  11:26            17,060 Assignment_4(D4).ipynb
# ...

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 3E6A-E9A2
#
#  Directory of C:\Users\Lenovo\Desktop\Python Bottcamp
#
# 31-12-2018  20:29             9,434  #day_1 27 december.ipynb
# 31-12-2018  12:27         6,660,049  #day_3 29 december.ipynb
# 31-12-2018  11:54             5,685  #day_4 31 december.ipynb
# 02-01-2019  12:51            12,462  #day_5 2nd january, web page image scrapper..ipynb
# 31-12-2018  10:24             3,528  ATM Prototype code in python.ipynb
# 01-01-2019  19:51             2,251  Web scrapping.ipynb
# 29-12-2018  09:20            13,407 #day_2 28 december.ipynb
# 02-01-2019  12:51    <DIR>          .
# 02-01-2019  12:51    <DIR>          ..
# 02-01-2019  12:36    <DIR>          .ipynb_checkpoints
# 29-12-2018  11:03             3,688 Assignment_1(D1).ipynb
# 29-12-2018  18:23             5,666 Assignment_2(D2).ipynb
# 31-12-2018  11:30             4,981 Assignment_3(D3).ipynb
# 02-01-2019  11:26            17,060 Assignment_4(D4).ipynb
# ...

# %%
# !cat testp.txt
# Out:
# 'cat' is not recognized as an internal or external command,
# operable program or batch file.

# %%
with open("testp.txt","r") as file:
    p=file.read()
    print(p)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-3f03fb46fbb3> in <module>
# ----> 1 with open("testp.txt","r") as file:
#       2     p=file.read()
#       3     print(p)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'testp.txt'
